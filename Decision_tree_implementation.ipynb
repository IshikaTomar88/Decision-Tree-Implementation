# %% [markdown]
# # Decision Tree Classifier on Iris Dataset
#
# Obective: demonstrates how to build, train, and visualize a Decision Tree Classifier using the Iris dataset.
#
# #### Steps:
#
# *   Import necessary libraries for data manipulation, visualization, and machine learning.
# *   Load and explore the Iris dataset.
# *   Split the dataset into training and testing sets.
# *   Build and train a Decision Tree Classifier model.
# *   Make predictions using the trained model.
# *   Visualize the decision tree to understand the model's decision rules.
# *   Save the decision tree visualization and a text representation of the tree.

# %% [markdown]
# # Import Libraries
#
# This section imports all the necessary libraries for data manipulation, visualization, and machine learning.

# %%
import pandas as pd
from matplotlib import pyplot as plt
from sklearn import tree

# %% [markdown]
# ## Load the Dataset
#
# Here we load the Iris dataset, which is a classic dataset used in machine learning for classification tasks. It contains measurements of iris flowers and their corresponding species.

# %%
# Loading iris dataset
from sklearn.datasets import load_iris
iris = load_iris()

# Create a pandas DataFrame for features
X = pd.DataFrame(iris.data, columns=iris.feature_names)

# Create a pandas Series for target variable
y = pd.Series(iris.target)

# %% [markdown]
# ## Explore the Dataset
#
# Before proceeding with the model training, it's good practice to explore the dataset to understand its structure and content.

# %%
print(X.head())
print(y.value_counts())
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
# 0    50
# 1    50
# 2    50
# Name: count, dtype: int64

# %% [markdown]
# ## Split the Dataset
#
# We split the dataset into training and testing sets to evaluate the model's performance on unseen data. The training set is used to train the model, and the testing set is used to assess its accuracy.

# %%
# Split the dataset into training and testing sets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %% [markdown]
# ## Check the Shape of the Datasets
#
# Let's check the dimensions of the training and testing sets to ensure the split was performed correctly.

# %%
# check the shape of the X_train, X_test, y_train, y_test
print("X train shape:", X_train.shape)
print("X test shape:", X_test.shape)
print("y train shape:", y_train.shape)
print("y test shape:", y_test.shape)
# Out:
# X train shape: (112, 4)
# X test shape: (38, 4)
# y train shape: (112,)
# y test shape: (38,)

# %% [markdown]
# ## Build and Train the Decision Tree Model
#
# Here we create an instance of the Decision Tree Classifier and train it on the training data. The model learns the decision rules from the training data to classify the iris species.

# %%
# Make an instance of the Decision Tree Classifier model
from sklearn.tree import DecisionTreeClassifier
clf_model = DecisionTreeClassifier()

# %%
# Train the model on the training data
# X_train: training features
# y_train: training target variable
clf_model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# ## Make Predictions
#
# Use the trained model to make predictions on the test set.

# %%
# Predict the labels of the unseen (test) data
# X_test: testing features
y_pred = clf_model.predict(X_test)

# %% [markdown]
# ## Visualize the Decision Tree
#
# Visualize the trained Decision Tree model. This helps in understanding the decision rules learned by the model.

# %%
# Create a figure for plotting the decision tree
fig = plt.figure()

# Plot the decision tree
tree.plot_tree(clf_model)

# Set the title of the plot
plt.title('Decision Tree Visualization')

# Display the plot
plt.show()

# %% [markdown]
# ## Save the Decision Tree Visualization
#
# Save the decision tree plot to a file for later use or sharing.

# %%
# Save the decision tree plot to a file
# 'decision_tree.png': the filename to save the plot
fig.savefig('decision_tree.png')

# Display the plot
display(fig)

# %% [markdown]
# # Visualize A Decision Tree (Alternative Method)
#
# This section demonstrates an alternative method to visualize a Decision Tree using the entire dataset.
#
# ## Load the dataset (Alternative Method)
#
# Load the dataset again for the alternative visualization method.

# %%
# Load the dataset
iris = load_iris()

# %% [markdown]
# ## Assign features and target (Alternative Method)
#
# Assign features and target variables for the alternative visualization method.

# %%
# Assign features to X and target to y
X = iris.data
y = iris.target

# %% [markdown]
# ## Train Decision Tree (Alternative Method)
#
# Train a Decision Tree model on the entire dataset for the alternative visualization method.

# %%
# Create a decision tree classifier object
clf_model = DecisionTreeClassifier()

# %%
# Train the model on the entire dataset
# X: features
# y: target variable
clf_model.fit(X, y)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# ## Export Text Representation of the Decision Tree
#
# Export the decision tree as a text representation. This provides a textual representation of the decision rules.

# %%
# Export the decision tree as a text representation
text_representation = tree.export_text(clf_model)

# Print the text representation of the decision tree
print(text_representation)
# Out:
# |--- feature_3 <= 0.80
# |   |--- class: 0
# |--- feature_3 >  0.80
# |   |--- feature_3 <= 1.75
# |   |   |--- feature_2 <= 4.95
# |   |   |   |--- feature_3 <= 1.65
# |   |   |   |   |--- class: 1
# |   |   |   |--- feature_3 >  1.65
# |   |   |   |   |--- class: 2
# |   |   |--- feature_2 >  4.95
# |   |   |   |--- feature_3 <= 1.55
# |   |   |   |   |--- class: 2
# |   |   |   |--- feature_3 >  1.55
# |   |   |   |   |--- feature_2 <= 5.45
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- feature_2 >  5.45
# |   |   |   |   |   |--- class: 2
# |   |--- feature_3 >  1.75
# |   |   |--- feature_2 <= 4.85
# |   |   |   |--- feature_1 <= 3.10
# |   |   |   |   |--- class: 2
# |   |   |   |--- feature_1 >  3.10
# |   |   |   |   |--- class: 1
# |   |   |--- feature_2 >  4.85
# |   |   |   |--- class: 2

# %% [markdown]
# ## Save the Text Representation
#
# Save the text representation of the decision tree to a file.

# %%
# Save the text representation of the decision tree to a file
# "decision_tree.log": the filename to save the text representation
# "w": opens the file in write mode
with open("decision_tree.log", "w") as fout:
    fout.write(text_representation)

# %% [markdown]
# ## Visualize the Decision Tree with Enhanced Options
#
# Visualize the decision tree with enhanced options like filled nodes, feature names, and class names. This provides a more informative visualization of the tree.

# %%
fig = plt.figure(figsize=(15, 10))
tree.plot_tree(clf_model, filled=True, feature_names=iris.feature_names, class_names=iris.target_names)

# Display the plot
display(fig)
# Out:
# [Text(0.5, 0.9166666666666666, 'petal width (cm) <= 0.8\ngini = 0.667\nsamples = 150\nvalue = [50, 50, 50]\nclass = setosa'),
#  Text(0.4230769230769231, 0.75, 'gini = 0.0\nsamples = 50\nvalue = [50, 0, 0]\nclass = setosa'),
#  Text(0.46153846153846156, 0.8333333333333333, 'True  '),
#  Text(0.5769230769230769, 0.75, 'petal width (cm) <= 1.75\ngini = 0.5\nsamples = 100\nvalue = [0, 50, 50]\nclass = versicolor'),
#  Text(0.5384615384615384, 0.8333333333333333, '  False'),
#  Text(0.3076923076923077, 0.5833333333333334, 'petal length (cm) <= 4.95\ngini = 0.168\nsamples = 54\nvalue = [0, 49, 5]\nclass = versicolor'),
#  Text(0.15384615384615385, 0.4166666666666667, 'petal width (cm) <= 1.65\ngini = 0.041\nsamples = 48\nvalue = [0, 47, 1]\nclass = versicolor'),
#  Text(0.07692307692307693, 0.25, 'gini = 0.0\nsamples = 47\nvalue = [0, 47, 0]\nclass = versicolor'),
#  Text(0.23076923076923078, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]\nclass = virginica'),
# ...

# %% [markdown]
# ## Conclusion
#
# Summarize the findings and insights gained from building, training, and visualizing the Decision Tree model on the Iris dataset. Discuss the model's performance and potential next steps.

# %% [markdown]
# # Decision Tree Classifier on Iris Dataset
#
# This notebook demonstrates how to build, train, and visualize a Decision Tree Classifier using the Iris dataset.
#
# ## Objective
#
# The objective of this notebook is to provide a step-by-step guide on:
#
# - Loading and exploring the Iris dataset.
# - Splitting the dataset into training and testing sets.
# - Building and training a Decision Tree Classifier model.
# - Making predictions using the trained model.
# - Visualizing the decision tree to understand the model's decision rules.
# - Saving the decision tree visualization and a text representation of the tree.
#
# ## Steps
#
# 1.  **Import Libraries:** Import necessary libraries for data manipulation (`pandas`), visualization (`matplotlib`), and machine learning (`sklearn`).
# 2.  **Load the Dataset:** Load the Iris dataset using `sklearn.datasets.load_iris`.
# 3.  **Explore the Dataset:** Examine the structure and content of the dataset by printing the head of the feature DataFrame and the value counts of the target variable.
# 4.  **Split the Dataset:** Split the dataset into training and testing sets using `sklearn.model_selection.train_test_split`.
# 5.  **Check the Shape of the Datasets:** Verify the dimensions of the training and testing sets.
# 6.  **Build and Train the Decision Tree Model:** Create an instance of `DecisionTreeClassifier` and train it on the training data using the `.fit()` method.
# 7.  **Make Predictions:** Use the trained model to make predictions on the test set using the `.predict()` method.
# 8.  **Visualize the Decision Tree:** Generate a visualization of the decision tree using `sklearn.tree.plot_tree`.
# 9.  **Save the Decision Tree Visualization:** Save the generated plot to a file (e.g., `decision_tree.png`).
# 10. **Visualize A Decision Tree (Alternative Method):** Demonstrate an alternative visualization method using the entire dataset.
# 11. **Export Text Representation of the Decision Tree:** Export a text-based representation of the decision tree rules using `sklearn.tree.export_text`.
# 12. **Save the Text Representation:** Save the text representation to a file (e.g., `decision_tree.log`).
# 13. **Visualize the Decision Tree with Enhanced Options:** Visualize the decision tree with enhanced options like filled nodes, feature names, and class names for better interpretability.
#
# ## Conclusion
#
# This notebook provides a comprehensive example of applying a Decision Tree Classifier to the Iris dataset. It covers the essential steps from data loading and preparation to model training, prediction, and visualization. The visualizations and text representation of the tree allow for a deeper understanding of how the model makes its predictions. This serves as a foundational example for applying Decision Trees to classification problems.

# %% [markdown]
# # Decision Tree Classifier on Iris Dataset
#
# This notebook demonstrates how to build, train, and visualize a Decision Tree Classifier using the Iris dataset.
#
# ## Objective
#
# The objective of this notebook is to provide a step-by-step guide on:
#
# - Loading and exploring the Iris dataset.
# - Splitting the dataset into training and testing sets.
# - Building and training a Decision Tree Classifier model.
# - Making predictions using the trained model.
# - Visualizing the decision tree to understand the model's decision rules.
# - Saving the decision tree visualization and a text representation of the tree.
#
# ## Steps
#
# 1.  **Import Libraries:** Import necessary libraries for data manipulation (`pandas`), visualization (`matplotlib`), and machine learning (`sklearn`).
# 2.  **Load the Dataset:** Load the Iris dataset using `sklearn.datasets.load_iris`.
# 3.  **Explore the Dataset:** Examine the structure and content of the dataset by printing the head of the feature DataFrame and the value counts of the target variable.
# 4.  **Split the Dataset:** Split the dataset into training and testing sets using `sklearn.model_selection.train_test_split`.
# 5.  **Check the Shape of the Datasets:** Verify the dimensions of the training and testing sets.
# 6.  **Build and Train the Decision Tree Model:** Create an instance of `DecisionTreeClassifier` and train it on the training data using the `.fit()` method.
# 7.  **Make Predictions:** Use the trained model to make predictions on the test set using the `.predict()` method.
# 8.  **Visualize the Decision Tree:** Generate a visualization of the decision tree using `sklearn.tree.plot_tree`.
# 9.  **Save the Decision Tree Visualization:** Save the generated plot to a file (e.g., `decision_tree.png`).
# 10. **Visualize A Decision Tree (Alternative Method):** Demonstrate an alternative visualization method using the entire dataset.
# 11. **Export Text Representation of the Decision Tree:** Export a text-based representation of the decision tree rules using `sklearn.tree.export_text`.
# 12. **Save the Text Representation:** Save the text representation to a file (e.g., `decision_tree.log`).
# 13. **Visualize the Decision Tree with Enhanced Options:** Visualize the decision tree with enhanced options like filled nodes, feature names, and class names for better interpretability.
#
# ## Conclusion
#
# This notebook provides a comprehensive example of applying a Decision Tree Classifier to the Iris dataset. It covers the essential steps from data loading and preparation to model training, prediction, and visualization. The visualizations and text representation of the tree allow for a deeper understanding of how the model makes its predictions. This serves as a foundational example for applying Decision Trees to classification problems.

# %% [markdown]
# # Decision Tree Classifier on Iris Dataset
#
# This notebook demonstrates how to build, train, and visualize a Decision Tree Classifier using the Iris dataset.
#
# ## Objective
#
# The objective of this notebook is to provide a step-by-step guide on:
#
# - Loading and exploring the Iris dataset.
# - Splitting the dataset into training and testing sets.
# - Building and training a Decision Tree Classifier model.
# - Making predictions using the trained model.
# - Visualizing the decision tree to understand the model's decision rules.
# - Saving the decision tree visualization and a text representation of the tree.
#
# ## Steps
#
# 1.  **Import Libraries:** Import necessary libraries for data manipulation (`pandas`), visualization (`matplotlib`), and machine learning (`sklearn`).
# 2.  **Load the Dataset:** Load the Iris dataset using `sklearn.datasets.load_iris`.
# 3.  **Explore the Dataset:** Examine the structure and content of the dataset by printing the head of the feature DataFrame and the value counts of the target variable.
# 4.  **Split the Dataset:** Split the dataset into training and testing sets using `sklearn.model_selection.train_test_split`.
# 5.  **Check the Shape of the Datasets:** Verify the dimensions of the training and testing sets.
# 6.  **Build and Train the Decision Tree Model:** Create an instance of `DecisionTreeClassifier` and train it on the training data using the `.fit()` method.
# 7.  **Make Predictions:** Use the trained model to make predictions on the test set using the `.predict()` method.
# 8.  **Visualize the Decision Tree:** Generate a visualization of the decision tree using `sklearn.tree.plot_tree`. You will need to add the generated image here.
# 9.  **Save the Decision Tree Visualization:** Save the generated plot to a file (e.g., `decision_tree.png`).
# 10. **Visualize A Decision Tree (Alternative Method):** Demonstrate an alternative visualization method using the entire dataset. You will need to add the generated image here.
# 11. **Export Text Representation of the Decision Tree:** Export a text-based representation of the decision tree rules using `sklearn.tree.export_text`. You can optionally include this text representation here.
# 12. **Save the Text Representation:** Save the text representation to a file (e.g., `decision_tree.log`).
# 13. **Visualize the Decision Tree with Enhanced Options:** Visualize the decision tree with enhanced options like filled nodes, feature names, and class names for better interpretability. You will need to add the generated image here.
#
# ## Conclusion
#
# This notebook provides a comprehensive example of applying a Decision Tree Classifier to the Iris dataset. It covers the essential steps from data loading and preparation to model training, prediction, and visualization. The visualizations and text representation of the tree allow for a deeper understanding of how the model makes its predictions. This serves as a foundational example for applying Decision Trees to classification problems.
